# %% [markdown]
# # **Task 1: YouTube Streamer Analysis**
#
# # **Intern career**
#
# ## Name : Jitha P Nair
# ## Dataset : Top 1000 Youtubers statistics
#
# Description: This dataset contains valuable
# information about the top YouTube streamers,
# including their ranking, categories, subscribers,
# country, visits, likes, comments, and more.
# Your task is to perform a comprehensive
# analysis of the dataset to extract insights
# about the top YouTube content creators.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("youtubers_df.csv")
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.sample(10)
# Out:
#      Rank             Username                 Categories   Suscribers  \
# 324   325               avicii  Música y baile, Películas   20700000.0
# 174   175     JYPEntertainment             Música y baile   27800000.0
# 1       2              MrBeast         Videojuegos, Humor  183500000.0
# 169   170         KidsRomaShow        Animación, Juguetes   28200000.0
# 417   418  GoodMythicalMorning            Comida y bebida   18400000.0
# 584   585           DaveAndAva             Música y baile   15400000.0
# 358   359                React                      Humor   20100000.0
# 57     58          MashaBearEN       Películas, Animación   43700000.0
# 38     39             shemaroo                        NaN   48800000.0
# 261   262       whitehillmusic             Música y baile   23300000.0
#
#             Country       Visits      Likes  Comments  \
# 324  Estados Unidos          0.0        0.0       0.0
# 174  Estados Unidos     177700.0     8700.0     668.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    306
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
df.describe()
# Out:
#               Rank    Suscribers        Visits         Likes       Comments
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean    500.500000  2.189440e+07  1.209446e+06  5.363259e+04    1288.768000
# std     288.819436  1.682775e+07  5.229942e+06  2.580457e+05    6778.188308
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     250.750000  1.380000e+07  3.197500e+04  4.717500e+02       2.000000
# 50%     500.500000  1.675000e+07  1.744500e+05  3.500000e+03      67.000000
# 75%     750.250000  2.370000e+07  8.654750e+05  2.865000e+04     472.000000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
df=df.dropna()

# %%
# Get unique values in the "Categories" column
unique_categories = df['Categories'].unique()

# Print the unique categories
print("Unique Categories:")
for category in unique_categories:
    print(category)
# Out:
# Unique Categories:
# Música y baile
# Videojuegos, Humor
# Educación
# Animación, Juguetes
# Películas, Videojuegos
# Juguetes
# Videojuegos
# Películas, Animación
# Películas
# Noticias y Política
# Animación, Humor
# Música y baile, Animación
# Música y baile, Películas
# Películas, Juguetes
# Películas, Humor
# Vlogs diarios
# Videojuegos, Juguetes
# Animación, Videojuegos
# Animación
# Música y baile, Humor
# Diseño/arte, DIY y Life Hacks
# Ciencia y tecnología
# Fitness, Salud y autoayuda
# Belleza, Moda
# Humor
# Comida y bebida
# Deportes
# Fitness
# Viajes, Espectáculos
# Comida y bebida, Salud y autoayuda
# Diseño/arte
# DIY y Life Hacks, Juguetes
# Educación, Juguetes
# Juguetes, Coches y vehículos
# Música y baile, Juguetes
# Animales y mascotas
# ASMR
# Moda
# DIY y Life Hacks
# Diseño/arte, Belleza
# Coches y vehículos
# Animación, Humor, Juguetes
# ASMR, Comida y bebida
# Comida y bebida, Juguetes
# Juguetes, DIY y Life Hacks

# %%
# Check for missing values
missing_values = df.isnull().sum()
print("Missing Values:")
print(missing_values)

# Mean imputation for numeric columns
df['Suscribers'].fillna(df['Suscribers'].mean(), inplace=True)

# Repeat this for other numeric columns with missing values

# Check if missing values have been handled
missing_values_after_imputation = df.isnull().sum()
print("\nMissing Values After Imputation:")
print(missing_values_after_imputation)
# Out:
# Missing Values:
# Rank          0
# Username      0
# Categories    0
# Suscribers    0
# Country       0
# Visits        0
# Likes         0
# Comments      0
# Links         0
# dtype: int64
#
# Missing Values After Imputation:
# Rank          0
# Username      0
# Categories    0
# Suscribers    0
# Country       0
# Visits        0
# Likes         0
# Comments      0
# Links         0
# dtype: int64
# C:\Users\Public\Documents\iSkysoft\CreatorTemp\ipykernel_2760\3187869369.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Suscribers'].fillna(df['Suscribers'].mean(), inplace=True)

# %%
# Data Analysis
# Find the top channels with the most subscribers
top_subscribers = df.sort_values(by='Suscribers', ascending=False).head(10)
print("\nTop Channels by Subscribers:")
print(top_subscribers)
# Out:
# Top Channels by Subscribers:
#     Rank            Username              Categories   Suscribers  \
# 0      1             tseries          Música y baile  249500000.0
# 1      2             MrBeast      Videojuegos, Humor  183500000.0
# 2      3           CoComelon               Educación  165500000.0
# 4      5       KidsDianaShow     Animación, Juguetes  113500000.0
# 5      6           PewDiePie  Películas, Videojuegos  111500000.0
# 6      7  LikeNastyaofficial                Juguetes  107500000.0
# 7      8         VladandNiki     Animación, Juguetes  101400000.0
# 8      9     zeemusiccompany          Música y baile   99700000.0
# 9     10                 WWE             Videojuegos   97200000.0
# 10    11           BLACKPINK          Música y baile   91300000.0
#
#            Country       Visits      Likes  Comments  \
# 0            India      86200.0     2700.0      78.0
# 1   Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
plt.figure(figsize=(10, 6))
plt.bar(top_subscribers['Username'], top_subscribers['Suscribers'])
plt.xlabel("Channel Username")
plt.ylabel("Subscribers")
plt.title("Top Channels by Subscribers")
plt.xticks(rotation=45)
plt.show()

# %%
# List of categorical column names you want to explore
categorical_columns = ['Categories', 'Country']

# Explore each categorical column
for column in categorical_columns:
    unique_values = df[column].unique()
    num_unique_values = len(unique_values)

    # Count the frequency of each unique value in the column
    value_counts = df[column].value_counts()

    print(f"Exploring column: {column}")
    print(f"Number of unique values: {num_unique_values}")

    # Display unique values and their frequencies
    print("Unique Values and Their Frequencies:")
    for value, count in value_counts.items():
        print(f"{value}: {count} ({count / len(df) * 100:.2f}%)")

    # Separate the output of different columns
    print("\n")
# Out:
# Exploring column: Categories
# Number of unique values: 45
# Unique Values and Their Frequencies:
# Música y baile: 160 (23.05%)
# Películas, Animación: 61 (8.79%)
# Música y baile, Películas: 41 (5.91%)
# Vlogs diarios: 37 (5.33%)
# Noticias y Política: 36 (5.19%)
# Películas, Humor: 34 (4.90%)
# Animación, Videojuegos: 34 (4.90%)
# Animación, Juguetes: 29 (4.18%)
# Animación, Humor: 27 (3.89%)
# Películas: 24 (3.46%)
# Educación: 24 (3.46%)
# Animación: 22 (3.17%)
# Videojuegos: 19 (2.74%)
# Videojuegos, Humor: 17 (2.45%)
# Música y baile, Animación: 16 (2.31%)
# Ciencia y tecnología: 14 (2.02%)
# Comida y bebida: 12 (1.73%)
# Humor: 10 (1.44%)
# Juguetes: 10 (1.44%)
# Películas, Juguetes: 9 (1.30%)
# Películas, Videojuegos: 8 (1.15%)
# Deportes: 8 (1.15%)
# Música y baile, Humor: 6 (0.86%)
# Juguetes, Coches y vehículos: 4 (0.58%)
# DIY y Life Hacks: 3 (0.43%)
# Fitness, Salud y autoayuda: 3 (0.43%)
# Videojuegos, Juguetes: 3 (0.43%)
# Animales y mascotas: 2 (0.29%)
# ...

# %%
# List of categorical column names you want to explore
categorical_columns = ['Categories', 'Country']  # Add more columns as needed

# Create bar charts for each categorical column
for column in categorical_columns:
    value_counts = df[column].value_counts()

    # Plot a bar chart
    plt.figure(figsize=(10, 6))
    value_counts.plot(kind='bar', color='skyblue')
    plt.title(f'Frequency Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.xticks(rotation=75)  # Rotate x-axis labels for readability
    plt.show()

# %%
# Create a histogram for the 'Suscribers' column
plt.figure(figsize=(10, 6))
sns.histplot(df['Suscribers'], bins=20, kde=True)
plt.title('Distribution of Subscribers')
plt.xlabel('Subscribers')
plt.ylabel('Frequency')
plt.show()

# %%
# Create a box plot to visualize 'Likes' by 'Categories'
plt.figure(figsize=(10, 8))
sns.boxplot(x='Categories', y='Likes', data=df)
plt.title('Likes by Category')
plt.xlabel('Category')
plt.ylabel('Likes')
plt.xticks(rotation=80)
plt.show()

# %%
# Create a count plot for the 'Country' column
plt.figure(figsize=(10, 6))
sns.countplot(x='Country', data=df, palette='viridis')
plt.title('Count of Channels by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Create a pair plot to explore relationships between numerical columns
sns.pairplot(df[['Suscribers', 'Visits', 'Likes', 'Comments']])
plt.show()

# %%
top_channels_subscribers = df.sort_values(by='Suscribers', ascending=False).head(10)
top_channels_subscribers
# Out:
#     Rank            Username              Categories   Suscribers  \
# 0      1             tseries          Música y baile  249500000.0
# 1      2             MrBeast      Videojuegos, Humor  183500000.0
# 2      3           CoComelon               Educación  165500000.0
# 4      5       KidsDianaShow     Animación, Juguetes  113500000.0
# 5      6           PewDiePie  Películas, Videojuegos  111500000.0
# 6      7  LikeNastyaofficial                Juguetes  107500000.0
# 7      8         VladandNiki     Animación, Juguetes  101400000.0
# 8      9     zeemusiccompany          Música y baile   99700000.0
# 9     10                 WWE             Videojuegos   97200000.0
# 10    11           BLACKPINK          Música y baile   91300000.0
#
#            Country       Visits      Likes  Comments  \
# 0            India      86200.0     2700.0      78.0
# 1   Estados Unidos  117400000.0  5300000.0   18500.0
# 2          Unknown    7000000.0    24700.0       0.0
# ...

# %%
top_channels_likes = df.sort_values(by='Likes', ascending=False).head(10)
top_channels_likes
# Out:
#      Rank                  Username              Categories   Suscribers  \
# 1       2                   MrBeast      Videojuegos, Humor  183500000.0
# 136   137                  MrBeast2           Vlogs diarios   31300000.0
# 153   154                 DaFuqBoom        Animación, Humor   29800000.0
# 341   342           triggeredinsaan                   Humor   20400000.0
# 488   489         BeastPhilanthropy         Comida y bebida   16900000.0
# 238   239                alanbecker  Animación, Videojuegos   24300000.0
# 306   307  khangsresearchcentre1685               Educación   21700000.0
# 590   591                   GoAmiGo           Vlogs diarios   15400000.0
# 366   367                    Vsauce    Ciencia y tecnología   19900000.0
# 131   132              fedevigevani        Animación, Humor   32000000.0
#
#             Country       Visits      Likes  Comments  \
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
top_channels_visits = df.sort_values(by='Visits', ascending=False).head(10)
top_channels_visits
# Out:
#      Rank           Username          Categories   Suscribers         Country  \
# 1       2            MrBeast  Videojuegos, Humor  183500000.0  Estados Unidos
# 136   137           MrBeast2       Vlogs diarios   31300000.0  Estados Unidos
# 153   154          DaFuqBoom    Animación, Humor   29800000.0  Estados Unidos
# 488   489  BeastPhilanthropy     Comida y bebida   16900000.0  Estados Unidos
# 958   959            dojacat      Música y baile   11900000.0  Estados Unidos
# 805   806            NickPro            Deportes   13200000.0  Estados Unidos
# 278   279        StokesTwins  Videojuegos, Humor   22700000.0  Estados Unidos
# 341   342    triggeredinsaan               Humor   20400000.0           India
# 43     44           A4a4a4a4    Animación, Humor   47300000.0           Rusia
# 376   377            Sidemen  Videojuegos, Humor   19500000.0     Reino Unido
#
#           Visits      Likes  Comments  \
# 1    117400000.0  5300000.0   18500.0
# ...

# %%
top_channels_comments = df.sort_values(by='Comments', ascending=False).head(10)
top_channels_comments
# Out:
#      Rank            Username              Categories   Suscribers  \
# 436   437  BispoBrunoLeonardo          Música y baile   18000000.0
# 153   154           DaFuqBoom        Animación, Humor   29800000.0
# 958   959             dojacat          Música y baile   11900000.0
# 177   178              DanTDM  Animación, Videojuegos   27800000.0
# 341   342     triggeredinsaan                   Humor   20400000.0
# 488   489   BeastPhilanthropy         Comida y bebida   16900000.0
# 43     44            A4a4a4a4        Animación, Humor   47300000.0
# 132   133               dream  Animación, Videojuegos   31900000.0
# 1       2             MrBeast      Videojuegos, Humor  183500000.0
# 131   132        fedevigevani        Animación, Humor   32000000.0
#
#             Country       Visits      Likes  Comments  \
# 436          Brasil     762100.0   276400.0  154000.0
# 153  Estados Unidos   52700000.0  1700000.0   82800.0
# 958  Estados Unidos   13600000.0   395300.0   73000.0
# ...

# %%
average_subscribers = df['Suscribers'].mean()
average_subscribers
# Out:
# 22415561.95965418

# %%
average_likes = df['Likes'].mean()
average_likes
# Out:
# 53473.59798270893

# %%
average_visits = df['Visits'].mean()
average_visits
# Out:
# 1210729.6829971182

# %%
average_comments = df['Comments'].mean()
average_comments
# Out:
# 1558.793948126801

# %%
# Group by 'Categories' and calculate the average subscribers and likes within each category
grouped_by_category = df.groupby('Categories').agg({
    'Suscribers': 'mean',
    'Likes': 'mean'
}).reset_index()

print("Average Subscribers and Likes by Category:")
print(grouped_by_category)
# Out:
# Average Subscribers and Likes by Category:
#                             Categories    Suscribers          Likes
# 0                                 ASMR  1.520000e+07    4100.000000
# 1                ASMR, Comida y bebida  1.300000e+07    8600.000000
# 2                            Animación  1.764091e+07   21413.454545
# 3                     Animación, Humor  2.078519e+07  145768.333333
# 4           Animación, Humor, Juguetes  1.390000e+07      37.000000
# 5                  Animación, Juguetes  2.937586e+07    2653.068966
# 6               Animación, Videojuegos  1.939412e+07   79294.029412
# 7                  Animales y mascotas  1.560000e+07  102750.000000
# 8                        Belleza, Moda  2.390000e+07   62300.000000
# 9                 Ciencia y tecnología  1.726429e+07   59283.142857
# 10                  Coches y vehículos  1.320000e+07   18150.000000
# 11                     Comida y bebida  1.612500e+07  128664.750000
# ...

# %%
# Group by 'Country' and calculate the total subscribers and likes within each country
grouped_by_country = df.groupby('Country').agg({
    'Suscribers': 'sum',
    'Likes': 'sum'
}).reset_index()

print("Total Subscribers and Likes by Country:")
print(grouped_by_country)
# Out:
# Total Subscribers and Likes by Country:
#            Country    Suscribers       Likes
# 0   Arabia Saudita  5.190000e+07    102000.0
# 1          Argelia  1.220000e+07     16000.0
# 2        Argentina  9.310000e+07    639400.0
# 3       Bangladesh  5.520000e+07      1048.0
# 4           Brasil  9.748000e+08   1267823.0
# 5         Colombia  3.067000e+08    863029.0
# 6           Egipto  3.100000e+07      6569.0
# 7           España  4.620000e+07    117700.0
# 8   Estados Unidos  5.002400e+09  23055596.0
# 9        Filipinas  1.679000e+08    309666.0
# 10         Francia  5.300000e+07     57337.0
# 11           India  2.974500e+09   4720797.0
# 12       Indonesia  6.246000e+08    380273.0
# 13            Iraq  5.030000e+07    386500.0
# 14           Japón  1.190000e+07     51000.0
# 15        Jordania  1.420000e+07      1900.0
# 16       Marruecos  2.580000e+07       195.0
# 17          México  8.256000e+08   2051015.0
# 18        Pakistán  1.097000e+08      4347.0
# ...

# %%
# Create a bar chart to visualize the average subscribers and likes by category
plt.figure(figsize=(12, 6))
plt.bar(grouped_by_category['Categories'], grouped_by_category['Suscribers'], label='Average Subscribers', alpha=0.7)
plt.bar(grouped_by_category['Categories'], grouped_by_category['Likes'], label='Average Likes', alpha=0.7)
plt.xlabel('Categories')
plt.ylabel('Counts')
plt.title('Average Subscribers and Likes by Category')
plt.xticks(rotation=80)
plt.legend()
plt.show()

# %%
# Create a bar chart to visualize the total subscribers and likes by country
plt.figure(figsize=(12, 6))
plt.bar(grouped_by_country['Country'], grouped_by_country['Suscribers'], label='Total Subscribers', alpha=0.7)
plt.bar(grouped_by_country['Country'], grouped_by_country['Likes'], label='Total Likes', alpha=0.7)
plt.xlabel('Country')
plt.ylabel('Counts')
plt.title('Total Subscribers and Likes by Country')
plt.xticks(rotation=65)
plt.legend()
plt.show()

# %%
# Calculate the distribution of categories
category_counts = df['Categories'].value_counts()

# Create a pie chart to visualize the distribution of categories
plt.figure(figsize=(15, 30))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.title('Distribution of Categories')
plt.show()

# %%
# Create a scatter plot to visualize the relationship between subscribers and likes
plt.figure(figsize=(10, 5))
plt.scatter(df['Suscribers'], df['Likes'], alpha=0.5)
plt.xlabel('Subscribers')
plt.ylabel('Likes')
plt.title('Scatter Plot of Subscribers vs. Likes')
plt.show()

# %%
average_subscribers = df['Suscribers'].mean()
average_visits = df['Visits'].mean()
average_likes = df['Likes'].mean()
average_comments = df['Comments'].mean()

# %%
above_average_streamers = df[(df['Suscribers'] > average_subscribers) &
                             (df['Visits'] > average_visits) &
                             (df['Likes'] > average_likes) &
                             (df['Comments'] > average_comments)]

# %%
top_performing_streamers = above_average_streamers.sort_values(by='Suscribers', ascending=False)

# %%
print("Top-Performing Content Creators:")
print(top_performing_streamers[['Username', 'Categories', 'Suscribers', 'Visits', 'Likes', 'Comments']])
# Out:
# Top-Performing Content Creators:
#                  Username                     Categories   Suscribers  \
# 1                 MrBeast             Videojuegos, Humor  183500000.0
# 5               PewDiePie         Películas, Videojuegos  111500000.0
# 26            dudeperfect                    Videojuegos   59700000.0
# 34            TaylorSwift                 Música y baile   54100000.0
# 39            JuegaGerman           Películas, Animación   48600000.0
# 43               A4a4a4a4               Animación, Humor   47300000.0
# 58              Mikecrack           Películas, Animación   43400000.0
# 62         KimberlyLoaiza                 Música y baile   42100000.0
# 70            JessNoLimit           Películas, Animación   39600000.0
# 96         TotalGaming093         Películas, Videojuegos   36300000.0
# 100            markiplier         Animación, Videojuegos   35500000.0
# 122               AboFlah         Animación, Videojuegos   32700000.0
# ...
